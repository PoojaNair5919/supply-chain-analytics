# %%
import numpy as np
import pandas as pd

# %%
df_orders = pd.read_csv("DataCoSupplyChainDataset.csv", encoding="latin1")

# %%
df_logs = pd.read_csv("tokenized_access_logs.csv", encoding="latin1")

# %%
df_desc = pd.read_csv("DescriptionDataCoSupplyChain.csv", encoding="latin1")

# %% [markdown]
# ## Checking DataCoSupplyChainDataset

# %%
df_orders.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df_orders.shape
# Out:
# (180519, 53)

# %%
df_orders.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df_orders["Order Item Id"].nunique()
# Out:
# 180519

# %%
df_orders.groupby("Order Id")["Order Item Id"].count().sort_values(ascending=False).head()
# Out:
# Order Id
# 65699    5
# 42199    5
# 13260    5
# 42258    5
# 42246    5
# Name: Order Item Id, dtype: int64

# %%
df_orders.isnull().sum().sort_values(ascending=False)
# Out:
# Product Description              180519
# Order Zipcode                    155679
# Customer Lname                        8
# Customer Zipcode                      3
# Type                                  0
# Order Profit Per Order                0
# Order Item Cardprod Id                0
# Order Item Discount                   0
# Order Item Discount Rate              0
# Order Item Id                         0
# Order Item Product Price              0
# Order Item Profit Ratio               0
# Order Item Quantity                   0
# Sales                                 0
# Order Item Total                      0
# Order Region                          0
# order date (DateOrders)               0
# Order State                           0
# Order Status                          0
# Product Card Id                       0
# Product Category Id                   0
# Product Image                         0
# Product Name                          0
# ...

# %%
df_orders.duplicated().sum()
# Out:
# 0

# %%
df_orders["Order Id"].nunique()
# Out:
# 65752

# %%
df_orders["Customer Id"].nunique()
# Out:
# 20652

# %%
df_orders["Product Card Id"].nunique()
# Out:
# 118

# %%
(df_orders["Customer Id"] == df_orders["Order Customer Id"]).value_counts()
# Out:
# True    180519
# Name: count, dtype: int64

# %%
df_orders[["order date (DateOrders)", "shipping date (DateOrders)"]].head()
# Out:
#   order date (DateOrders) shipping date (DateOrders)
# 0         1/31/2018 22:56             2/3/2018 22:56
# 1         1/13/2018 12:27            1/18/2018 12:27
# 2         1/13/2018 12:06            1/17/2018 12:06
# 3         1/13/2018 11:45            1/16/2018 11:45
# 4         1/13/2018 11:24            1/15/2018 11:24

# %%
df_orders["order date (DateOrders)"] = pd.to_datetime(df_orders["order date (DateOrders)"])

# %%
df_orders["shipping date (DateOrders)"] = pd.to_datetime(df_orders["shipping date (DateOrders)"])

# %%
df_orders[["Days for shipping (real)", "Days for shipment (scheduled)"]].describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000

# %%
columns_to_drop = [
    "Product Description",
    "Order Zipcode",
    "Customer Email",
    "Customer Password",
    "Customer Fname",
    "Customer Lname",
    "Customer Street",
    "Product Image",
    "Order Customer Id"
]

df_clean = df_orders.drop(columns=columns_to_drop)

# %%
df_clean.shape
# Out:
# (180519, 44)

# %%
df_orders["Order Profit Per Order"].describe()
# Out:
# count    180519.000000
# mean         21.974989
# std         104.433526
# min       -4274.979980
# 25%           7.000000
# 50%          31.520000
# 75%          64.800003
# max         911.799988
# Name: Order Profit Per Order, dtype: float64

# %%
(df_orders["Order Profit Per Order"] < 0).sum()
# Out:
# 33784

# %%
((df_orders["Order Profit Per Order"] < 0).sum() / len(df_orders)) * 100
# Out:
# 18.714927514555253

# %%
(df_orders["Benefit per order"] == df_orders["Order Profit Per Order"]).value_counts()
# Out:
# True    180519
# Name: count, dtype: int64

# %%
df_clean["Delivery Delay"] = df_clean["Days for shipping (real)"] - df_clean["Days for shipment (scheduled)"]

# %%
(df_orders["shipping date (DateOrders)"] < df_orders["order date (DateOrders)"]).sum()
# Out:
# 0

# %%
df_clean["Delivery Delay"].describe()
# Out:
# count    180519.000000
# mean          0.565807
# std           1.490966
# min          -2.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           4.000000
# Name: Delivery Delay, dtype: float64

# %%
df_clean["Delivery Status Derived"] = df_clean["Delivery Delay"].apply(
    lambda x: "Delayed" if x > 0 else "On Time"
)

# %%
(df_clean["Delivery Delay"] > 0).mean() * 100
# Out:
# 57.279289160697765

# %% [markdown]
# ## Checking DescriptionDataCoSupplyChain

# %%
df_desc.shape
# Out:
# (52, 2)

# %%
df_desc.head()
# Out:
#                           FIELDS  \
# 0                           Type
# 1  Days for shipping (real)
# 2  Days for shipment (scheduled)
# 3              Benefit per order
# 4             Sales per customer
#
#                                          DESCRIPTION
# 0                        :  Type of transaction made
# 1   :  Actual shipping days of the purchased product
# 2  :  Days of scheduled delivery of the purchased...
# 3                       :  Earnings per order placed
# 4      :  Total sales per customer made per customer

# %%
df_desc.columns
# Out:
# Index(['FIELDS', 'DESCRIPTION'], dtype='object')

# %% [markdown]
# ## Checking tokenized_access_logs

# %%
df_logs.shape
# Out:
# (469977, 8)

# %%
df_logs.head()
# Out:
#                                       Product             Category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#             Date Month  Hour Department              ip  \
# 0  9/1/2017 6:00   Sep     6   fitness     37.97.182.65
# 1  9/1/2017 6:00   Sep     6  fan shop     206.56.112.1
# 2  9/1/2017 6:00   Sep     6   apparel    215.143.180.0
# 3  9/1/2017 6:00   Sep     6  footwear     206.56.112.1
# 4  9/1/2017 6:01   Sep     6  fan shop   136.108.56.242
#
#                                                  url
# 0  /department/fitness/category/baseball%20&%20so...
# 1  /department/fan%20shop/category/hunting%20&%20...
# 2  /department/apparel/category/featured%20shops/...
# ...

# %%
df_logs.columns
# Out:
# Index(['Product', 'Category', 'Date', 'Month', 'Hour', 'Department', 'ip',
#        'url'],
#       dtype='object')

# %%
df_clean["Product Card Id"].nunique()
# Out:
# 118

# %%
df_clean["Product Name"].nunique()
# Out:
# 118

# %%
df_clean["Delivery Status Derived"] = df_clean["Delivery Delay"].apply(
    lambda x: "Delayed" if x > 0 else "On Time"
)

# %%
df_clean["Delivery Status Derived"].value_counts()
# Out:
# Delivery Status Derived
# Delayed    103400
# On Time     77119
# Name: count, dtype: int64

# %%
(df_clean["Sales"] == df_clean["Order Item Total"]).value_counts()
# Out:
# False    170491
# True      10028
# Name: count, dtype: int64

# %%
df_clean.to_csv("supply_chain_clean.csv", index=False)
